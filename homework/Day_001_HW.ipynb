# %% [markdown]
# 作業1：請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下
#
# Dataset: Suicide Rates Overview 1985 to 2016 (https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016)
#
# 1. 你選的這組資料為何重要: This dataset provides crucial information to find signals correlated to increased suicide rates among different cohorts globally.
# 2. 資料從何而來 (tips - 譬如提供者是誰、以什麼方式蒐集): UNDP, World Bank, WHO
# 3. 蒐集而來的資料型態為何: CSV
# 4. 這組資料想解決的問題如何評估: From this compiled dataset, one can investigate the different attributes correlated to an increased suicide rate and hence create a predictive algorithm to help decrease the suicide rate.

# %% [markdown]
# 作業2：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips - 如何定義 「提升業績 & 你的假設」): 透過數學模型的建立以及實際測試，可得出每一個參數 (譬如說不同時段及區域所規劃的司機人數和車種、跳表費率、服務項目、優惠方案、等) 的理想值，以便將載客收益最大化。
# 2. 資料從何而來 (tips - 哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集): 乘客反饋 (以開放或封閉式問卷來得知每一乘客的搭乘體驗)、不同時段及區域所對應到的載客量 (可由司機以GPS來記錄每一旅次的起始地、目的地、所耗時間、費用)
# 3. 蒐集而來的資料型態為何: 開放或封閉式問卷 (等候時間、搭乘體驗、整體滿意度)，結構化資料及圖表 (不同時段及區域所對應到的載客量、每一旅次的收益/耗時/耗油量/等)
# 4. 你要回答的問題，其如何評估 (tips - 你的假設如何驗證): 根據以上資料來建構一個模型，以便計算出最大載客收益時的參數。再由理論數據來調整不同時段及區域所規劃的司機人數和車種、跳表費率、服務項目、優惠方案、等參數，並以調整前後的業績做為標準以找到每一參數的理想值。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y_data, y_reg):
    """
        - y_data: 實際值
        - y_reg: 預測值
    """
    return sum((y_data - y_reg) ** 2) / len(y_data)

# %%
def mean_absolute_error(y, yp):
    """
        - y: 實際值
        - yp: 預測值
    """
    return sum(abs(y - yp)) / len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 249.600
# The Mean absolute error is 12.605
